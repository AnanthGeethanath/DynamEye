# %%
# imports

# %% [markdown]
# # 01 Dynamic zoom
#
# The main objective is to implement efficient code for increasing and decreasing zoom. This is one of the core features. This experiment needs to prove choice of libraries and code through standard benchmarks.

# %% [markdown]
# **Please do not delete this cell till the expt is complete**
#
# 1. Code coverage > 80%
# 2. Zenof python to lead coding standards
# 3. Conclusion to prove hypotheses through standard statistical tests
# 4. Always squash commit
# 5. Maintain linear history
